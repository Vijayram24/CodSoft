# %%
import pandas as pd

# %%
df = pd.read_csv(r'Titanic-Dataset.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.shape
# Out:
# (891, 12)

# %%
df.drop_duplicates(inplace= True)

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isnull().sum().sum()
# Out:
# 866

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.Age.fillna(df.Age.mode()[0] , inplace = True)
# Out:
# C:\Users\Pankaj Negi\AppData\Local\Temp\ipykernel_16224\423832694.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Age.fillna(df.Age.mode()[0] , inplace = True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop("Cabin" , axis = 1 , inplace = True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
df.Embarked.fillna(method = 'bfill', inplace = True)
# Out:
# C:\Users\Pankaj Negi\AppData\Local\Temp\ipykernel_16224\2252074174.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Embarked.fillna(method = 'bfill', inplace = True)
# C:\Users\Pankaj Negi\AppData\Local\Temp\ipykernel_16224\2252074174.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.Embarked.fillna(method = 'bfill', inplace = True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
for i in df.columns :
    sns.boxplot(df[i])
    plt.show()

# %%
df.Sex.replace({"male" : 1 , 'female' : 0} , inplace = True)
# Out:
# C:\Users\Pankaj Negi\AppData\Local\Temp\ipykernel_16264\2077485493.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Sex.replace({"male" : 1 , 'female' : 0} , inplace = True)
# C:\Users\Pankaj Negi\AppData\Local\Temp\ipykernel_16264\2077485493.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.Sex.replace({"male" : 1 , 'female' : 0} , inplace = True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Embarked
# 0         A/5 21171   7.2500        S
# 1          PC 17599  71.2833        C
# 2  STON/O2. 3101282   7.9250        S
# 3            113803  53.1000        S
# 4            373450   8.0500        S

# %%
df.drop("Name" , axis = 1 , inplace = True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0            1         0       3    1  22.0      1      0         A/5 21171
# 1            2         1       1    0  38.0      1      0          PC 17599
# 2            3         1       3    0  26.0      0      0  STON/O2. 3101282
# 3            4         1       1    0  35.0      1      0            113803
# 4            5         0       3    1  35.0      0      0            373450
#
#       Fare Embarked
# 0   7.2500        S
# 1  71.2833        C
# 2   7.9250        S
# 3  53.1000        S
# 4   8.0500        S

# %%
df.Ticket.value_counts()
# Out:
# Ticket
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: count, Length: 681, dtype: int64

# %%
df.drop("Ticket" , axis = 1 , inplace = True )

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    1  22.0      1      0   7.2500        S
# 1            2         1       1    0  38.0      1      0  71.2833        C
# 2            3         1       3    0  26.0      0      0   7.9250        S
# 3            4         1       1    0  35.0      1      0  53.1000        S
# 4            5         0       3    1  35.0      0      0   8.0500        S

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df.Embarked = le.fit_transform(df.Embarked)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0            1         0       3    1  22.0      1      0   7.2500         2
# 1            2         1       1    0  38.0      1      0  71.2833         0
# 2            3         1       3    0  26.0      0      0   7.9250         2
# 3            4         1       1    0  35.0      1      0  53.1000         2
# 4            5         0       3    1  35.0      0      0   8.0500         2

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000 -0.005007 -0.035144  0.042939  0.036186 -0.057527
# Survived       -0.005007  1.000000 -0.338481 -0.543351 -0.052872 -0.035322
# Pclass         -0.035144 -0.338481  1.000000  0.131900 -0.356187  0.083081
# Sex             0.042939 -0.543351  0.131900  1.000000  0.073377 -0.114631
# Age             0.036186 -0.052872 -0.356187  0.073377  1.000000 -0.232411
# SibSp          -0.057527 -0.035322  0.083081 -0.114631 -0.232411  1.000000
# Parch          -0.001652  0.081629  0.018443 -0.245489 -0.155118  0.414838
# Fare            0.012658  0.257307 -0.549500 -0.182333  0.107554  0.159651
# Embarked        0.008875 -0.170943  0.166223  0.111894 -0.007197  0.069444
#
#                 Parch      Fare  Embarked
# PassengerId -0.001652  0.012658  0.008875
# Survived     0.081629  0.257307 -0.170943
# Pclass       0.018443 -0.549500  0.166223
# Sex         -0.245489 -0.182333  0.111894
# Age         -0.155118  0.107554 -0.007197
# SibSp        0.414838  0.159651  0.069444
# Parch        1.000000  0.216225  0.041064
# Fare         0.216225  1.000000 -0.227015
# Embarked     0.041064 -0.227015  1.000000

# %%
sns.heatmap(df.corr() , annot = True , cmap = 'coolwarm')
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Fare', 'Embarked'],
#       dtype='object')

# %%
y = df["Survived"]
x = df.drop(columns = ["Survived" ,'PassengerId' , 'SibSp' ] , axis = 1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test ,y_train , y_test = train_test_split(x , y , train_size = 0.8 , random_state = 0)

# %%
x_train.shape , x_test.shape ,y_train.shape , y_test.shape
# Out:
# ((712, 6), (179, 6), (712,), (179,))

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(max_iter=1000)

# %%
model.fit(x_train , y_train )
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_pred , y_test)
# Out:
# 0.18435754189944134

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_pred  , y_test)
# Out:
# 0.8156424581005587

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model1 = DecisionTreeClassifier(random_state = 500)

# %%
model1.fit(x_train , y_train)
# Out:
# DecisionTreeClassifier(random_state=500)

# %%
y_pred = model1.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error

# %%
y_pred.shape
# Out:
# (179,)

# %%
y_test.shape
# Out:
# (179,)

# %%
x_train.shape
# Out:
# (712, 6)

# %%
mean_absolute_error(y_test , y_pred)
# Out:
# 0.18994413407821228

# %%
accuracy_score(y_test , y_pred)
# Out:
# 0.8100558659217877

# %%
from sklearn.svm import SVC

# %%
model2 = SVC(kernel = 'linear')

# %%
model2.fit(x_train , y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = model2.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error , accuracy_score

# %%
mean_absolute_error(y_test , y_pred)
# Out:
# 0.2122905027932961

# %% [markdown]
# accuracy_score(y_test , y_pred)

# %%
accuracy_score(y_test , y_pred)
# Out:
# 0.7877094972067039

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model3 = GaussianNB()

# %%
model3.fit(x_train , y_train)
# Out:
# GaussianNB()

# %%
y_pred = model3.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error , accuracy_score

# %%
mean_absolute_error(y_pred , y_test)
# Out:
# 0.2011173184357542

# %%
accuracy_score(y_pred , y_test)
# Out:
# 0.7988826815642458
